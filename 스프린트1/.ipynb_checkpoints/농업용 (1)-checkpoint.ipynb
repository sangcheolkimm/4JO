# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
e_df = pd.read_excel('광주광역시 전력사용량 2018~2022 (1).xlsx')

# %%
e_df.drop(columns='Unnamed: 0',inplace=True)

# %%
e_farm_df=e_df[e_df['계약종별']=='농사용']

# %%
e_farm_df=e_farm_df.melt(id_vars=['연도','시도','시군구','계약종별'])
e_farm_df
# Out:
#        연도     시도  시군구 계약종별 variable    value
# 0    2018  광주광역시   동구  농사용       1월   105784
# 1    2018  광주광역시   서구  농사용       1월   655175
# 2    2018  광주광역시   북구  농사용       1월  2434390
# 3    2018  광주광역시  광산구  농사용       1월  5966909
# 4    2018  광주광역시   남구  농사용       1월  1061988
# ..    ...    ...  ...  ...      ...      ...
# 295  2022  광주광역시   동구  농사용      12월   164844
# 296  2022  광주광역시   서구  농사용      12월   382922
# 297  2022  광주광역시   북구  농사용      12월  1663350
# 298  2022  광주광역시  광산구  농사용      12월  5541983
# 299  2022  광주광역시   남구  농사용      12월   871011
#
# [300 rows x 6 columns]

# %%
e_farm_df['월별']=e_farm_df['variable'].rename('월별')
e_farm_df['전력사용량']=e_farm_df['value'].rename('전력사용량')

# %%
# e_farm_df.drop(columns=['variable','value'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23076\1821744958.py in <module>
# ----> 1 e_farm_df.drop(columns=['variable','value'],inplace=True)
#       2 e_farm_df
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['variable', 'value'] not found in axis"

# %%
e_farm_df
# Out:
#        연도     시도  시군구 계약종별   월별    전력사용량
# 0    2018  광주광역시   동구  농사용   1월   105784
# 1    2018  광주광역시   서구  농사용   1월   655175
# 2    2018  광주광역시   북구  농사용   1월  2434390
# 3    2018  광주광역시  광산구  농사용   1월  5966909
# 4    2018  광주광역시   남구  농사용   1월  1061988
# ..    ...    ...  ...  ...  ...      ...
# 295  2022  광주광역시   동구  농사용  12월   164844
# 296  2022  광주광역시   서구  농사용  12월   382922
# 297  2022  광주광역시   북구  농사용  12월  1663350
# 298  2022  광주광역시  광산구  농사용  12월  5541983
# 299  2022  광주광역시   남구  농사용  12월   871011
#
# [300 rows x 6 columns]

# %%
farm_east = e_farm_df[e_farm_df['시군구']=='동구']
farm_west = e_farm_df[e_farm_df['시군구']=='서구']
farm_south = e_farm_df[e_farm_df['시군구']=='남구']
farm_north = e_farm_df[e_farm_df['시군구']=='북구']

# %%
farm_east_df = farm_east.pivot_table(index='월별',columns='연도',values='전력사용량')
farm_west_df = farm_west.pivot_table(index='월별',columns='연도',values='전력사용량')
farm_south_df = farm_south.pivot_table(index='월별',columns='연도',values='전력사용량')
farm_north_df = farm_north.pivot_table(index='월별',columns='연도',values='전력사용량')

# %%
farm_north_df = farm_north.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '북구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

fig, ax = plt.subplots(figsize=(10, 3))
farm_north_df.plot(ax=ax, lw=2, label='North')

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xlim(left=1, right=12)  
ax.set_xticks(range(0, 12)) 
ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'])
ax.legend(loc=0)
plt.grid()

farm_east_df = farm_east.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '동구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

fig, ax = plt.subplots(figsize=(10, 3))
farm_east_df.plot(ax=ax, lw=2, label='East')

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xlim(left=1, right=12)  
ax.set_xticks(range(0, 12)) 
ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'])
ax.legend(loc=0)
plt.grid()


farm_south_df = farm_south.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '남구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

fig, ax = plt.subplots(figsize=(10, 3))
farm_south_df.plot(ax=ax, lw=2, label='South')

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xlim(left=1, right=12) 
ax.set_xticks(range(0, 12))
ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'])
ax.legend(loc=0)
plt.grid()

farm_west_df = farm_west.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '서구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

fig, ax = plt.subplots(figsize=(10, 3))
farm_west_df.plot(ax=ax, lw=2, label='West')

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xlim(left=1, right=12) 
ax.set_xticks(range(0, 12))
ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'])
ax.legend(loc=0)
plt.grid()

plt.show()

# %%
farm_north_df = farm_north.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '북구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

ax = farm_north_df.plot(kind='bar', figsize=(10, 5), width=0.8, edgecolor='gray', linewidth=1)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'], rotation=0)
ax.legend(loc=0)
plt.grid()

farm_east_df = farm_east.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '동구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

ax = farm_east_df.plot(kind='bar', figsize=(10, 5), width=0.8, edgecolor='gray', linewidth=1)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'], rotation=0)
ax.legend(loc=0)
plt.grid()

farm_west_df = farm_west.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '서구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

ax = farm_west_df.plot(kind='bar', figsize=(10, 5), width=0.8, edgecolor='gray', linewidth=1)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'], rotation=0)
ax.legend(loc=0)
plt.grid()

farm_south_df = farm_south.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '남구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

ax = farm_south_df.plot(kind='bar', figsize=(10, 5), width=0.8, edgecolor='gray', linewidth=1)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'], rotation=0)
ax.legend(loc=0)
plt.grid()
plt.show()
