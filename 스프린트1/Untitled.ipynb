# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
dd=pd.read_excel('광주광역시 전력사용량.xlsx')

# %%
dd.drop(columns='Unnamed: 0',inplace=True)

# %%
dd_t=dd.melt(id_vars=['연도','시도','시군구','계약종별'],value_vars='')

# %%
dd_gwang=dd[dd['시군구']=='광산구']
dd_gwang
# Out:
#        연도     시도  시군구 계약종별         1월         2월         3월         4월  \
# 24   2018  광주광역시  광산구  주택용   48366452   49271579   42711658   44243142
# 25   2018  광주광역시  광산구  일반용   72018321   74730914   59422888   57129086
# 26   2018  광주광역시  광산구  교육용    6829289    6175335    5028630    4682165
# 27   2018  광주광역시  광산구  산업용  179231872  166663085  166241926  167847484
# 28   2018  광주광역시  광산구  농사용    5966909    6368285    4452512    3061473
# 29   2018  광주광역시  광산구  가로등    2597929    2490552    2212936    2223167
# 30   2018  광주광역시  광산구  심 야    4029971    4240071    3331566    2370931
# 31   2018  광주광역시  광산구  합 계  319040743  309939821  283402116  281557448
# 64   2019  광주광역시  광산구  주택용   49335741   49297564   43222980   45818755
# 65   2019  광주광역시  광산구  일반용   70389750   67558429   58048643   57617660
# 66   2019  광주광역시  광산구  교육용    6741847    4656063    4818429    5309247
# 67   2019  광주광역시  광산구  산업용  176730544  153216420  162070368  171906708
# ...

# %%
dd_t=dd_gwang.melt(id_vars=['연도','시도','시군구','계약종별'])
dd_t['월별']=dd_t['variable'].rename('월별')
dd_t['전력량']=dd_t['value'].rename('전력량')
dd_t.drop(columns=['value','variable'],inplace=True)
dd_t[]
# Out:
#        연도     시도  시군구 계약종별   월별        전력량
# 0    2018  광주광역시  광산구  주택용   1월   48366452
# 1    2018  광주광역시  광산구  일반용   1월   72018321
# 2    2018  광주광역시  광산구  교육용   1월    6829289
# 3    2018  광주광역시  광산구  산업용   1월  179231872
# 4    2018  광주광역시  광산구  농사용   1월    5966909
# ..    ...    ...  ...  ...  ...        ...
# 475  2022  광주광역시  광산구  산업용  12월  160994244
# 476  2022  광주광역시  광산구  농사용  12월    5541983
# 477  2022  광주광역시  광산구  가로등  12월    2499654
# 478  2022  광주광역시  광산구  심 야  12월    1885138
# 479  2022  광주광역시  광산구  합 계  12월  294178552
#
# [480 rows x 6 columns]

# %%
dd_g=dd_t.groupby(['연도','계약종별'])['전력량'].sum()
dd_f=dd_g.to_frame()

# %%
dd_k=dd_f.T
dd_k
# dd_p=dd_f.drop(columns=['가로등','심야','일반용'],inplace=True)
# Out:
#                   전력량
# 연도   계약종별
# 2018 가로등     26556211
#      교육용     59973643
#      농사용     44268945
#      산업용   1998991788
#      심 야     22813457
#      일반용    763345116
#      주택용    572594730
#      합 계   3488543890
# 2019 가로등     27504264
#      교육용     57875623
#      농사용     43099103
#      산업용   1937191566
#      심 야     20692287
#      일반용    753314519
#      주택용    574824654
#      합 계   3414502016
# 2020 가로등     27633657
#      교육용     47402021
#      농사용     43446254
#      산업용   1865319845
#      심 야     19023452
#      일반용    747436864
#      주택용    612635003
#      합 계   3362897096
# 2021 가로등     26545302
#      교육용     55949985
#      농사용     46066634
#      산업용   2064643990
#      심 야     17767457
#      일반용    791144247
#      주택용    635234560
#      합 계   3637352175
# 2022 가로등     27043015
#      교육용     58989991
#      농사용     55001356
#      산업용   1999018832
#      심 야     16089405
#      일반용    841734611
#      주택용    647391525
#      합 계   3645268735

# %%
pd.read_excel('계약종별 1년치 총 합계.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26324\251857016.py in <module>
# ----> 1 pd.read_excel('계약종별 1년치 총 합계.xlsx')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455     if not isinstance(io, ExcelFile):
#     456         should_close = True
# ...
