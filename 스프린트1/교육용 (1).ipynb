# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
e_df = pd.read_excel('광주광역시 전력사용량 2018_2022 (1).xlsx')

# %%
e_df.drop(columns='Unnamed: 0',inplace=True)

# %%
e_edu_df=e_df[e_df['계약종별']=='교육용']

# %%
e_edu_df=e_edu_df.melt(id_vars=['연도','시도','시군구','계약종별'])
e_edu_df
# Out:
#        연도     시도  시군구 계약종별 variable     value
# 0    2018  광주광역시   동구  교육용       1월   4175925
# 1    2018  광주광역시   서구  교육용       1월   2568928
# 2    2018  광주광역시   북구  교육용       1월  14609186
# 3    2018  광주광역시  광산구  교육용       1월   6829289
# 4    2018  광주광역시   남구  교육용       1월   3626487
# ..    ...    ...  ...  ...      ...       ...
# 295  2022  광주광역시   동구  교육용      12월   3536312
# 296  2022  광주광역시   서구  교육용      12월   2340582
# 297  2022  광주광역시   북구  교육용      12월  15457204
# 298  2022  광주광역시  광산구  교육용      12월   6157714
# 299  2022  광주광역시   남구  교육용      12월   3668155
#
# [300 rows x 6 columns]

# %%
e_edu_df['월별']=e_edu_df['variable'].rename('월별')
e_edu_df['전력사용량']=e_edu_df['value'].rename('전력사용량')

# %%
e_edu_df
# Out:
#        연도     시도  시군구 계약종별 variable     value   월별     전력사용량
# 0    2018  광주광역시   동구  교육용       1월   4175925   1월   4175925
# 1    2018  광주광역시   서구  교육용       1월   2568928   1월   2568928
# 2    2018  광주광역시   북구  교육용       1월  14609186   1월  14609186
# 3    2018  광주광역시  광산구  교육용       1월   6829289   1월   6829289
# 4    2018  광주광역시   남구  교육용       1월   3626487   1월   3626487
# ..    ...    ...  ...  ...      ...       ...  ...       ...
# 295  2022  광주광역시   동구  교육용      12월   3536312  12월   3536312
# 296  2022  광주광역시   서구  교육용      12월   2340582  12월   2340582
# 297  2022  광주광역시   북구  교육용      12월  15457204  12월  15457204
# 298  2022  광주광역시  광산구  교육용      12월   6157714  12월   6157714
# 299  2022  광주광역시   남구  교육용      12월   3668155  12월   3668155
#
# [300 rows x 8 columns]

# %%
# e_edu_df.drop(columns=['variable','value'],inplace=True)

# %%
e_edu_df
# Out:
#        연도     시도  시군구 계약종별   월별     전력사용량
# 0    2018  광주광역시   동구  교육용   1월   4175925
# 1    2018  광주광역시   서구  교육용   1월   2568928
# 2    2018  광주광역시   북구  교육용   1월  14609186
# 3    2018  광주광역시  광산구  교육용   1월   6829289
# 4    2018  광주광역시   남구  교육용   1월   3626487
# ..    ...    ...  ...  ...  ...       ...
# 295  2022  광주광역시   동구  교육용  12월   3536312
# 296  2022  광주광역시   서구  교육용  12월   2340582
# 297  2022  광주광역시   북구  교육용  12월  15457204
# 298  2022  광주광역시  광산구  교육용  12월   6157714
# 299  2022  광주광역시   남구  교육용  12월   3668155
#
# [300 rows x 6 columns]

# %%
e_edu_df
# Out:
#        연도     시도  시군구 계약종별   월별     전력사용량
# 0    2018  광주광역시   동구  교육용   1월   4175925
# 1    2018  광주광역시   서구  교육용   1월   2568928
# 2    2018  광주광역시   북구  교육용   1월  14609186
# 3    2018  광주광역시  광산구  교육용   1월   6829289
# 4    2018  광주광역시   남구  교육용   1월   3626487
# ..    ...    ...  ...  ...  ...       ...
# 295  2022  광주광역시   동구  교육용  12월   3536312
# 296  2022  광주광역시   서구  교육용  12월   2340582
# 297  2022  광주광역시   북구  교육용  12월  15457204
# 298  2022  광주광역시  광산구  교육용  12월   6157714
# 299  2022  광주광역시   남구  교육용  12월   3668155
#
# [300 rows x 6 columns]

# %%
edu_east = e_edu_df[e_edu_df['시군구']=='동구']
edu_west = e_edu_df[e_edu_df['시군구']=='서구']
edu_south = e_edu_df[e_edu_df['시군구']=='남구']
edu_north = e_edu_df[e_edu_df['시군구']=='북구']
edu_gwang = e_edu_df[e_edu_df['시군구']=='광산구']

# %%
e_edu_df
# Out:
#        연도     시도  시군구 계약종별   월별     전력사용량
# 0    2018  광주광역시   동구  교육용   1월   4175925
# 1    2018  광주광역시   서구  교육용   1월   2568928
# 2    2018  광주광역시   북구  교육용   1월  14609186
# 3    2018  광주광역시  광산구  교육용   1월   6829289
# 4    2018  광주광역시   남구  교육용   1월   3626487
# ..    ...    ...  ...  ...  ...       ...
# 295  2022  광주광역시   동구  교육용  12월   3536312
# 296  2022  광주광역시   서구  교육용  12월   2340582
# 297  2022  광주광역시   북구  교육용  12월  15457204
# 298  2022  광주광역시  광산구  교육용  12월   6157714
# 299  2022  광주광역시   남구  교육용  12월   3668155
#
# [300 rows x 6 columns]

# %%
edu_east_df = edu_east.pivot_table(index='월별',columns='연도',values='전력사용량')
edu_west_df = edu_west.pivot_table(index='월별',columns='연도',values='전력사용량')
edu_south_df = edu_south.pivot_table(index='월별',columns='연도',values='전력사용량')
edu_north_df = edu_north.pivot_table(index='월별',columns='연도',values='전력사용량')
edu_gwang_df = edu_gwang.pivot_table(index='월별',columns='연도',values='전력사용량')

# %%
# 교육용
edu_north_df = edu_north.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '북구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

fig, ax = plt.subplots(figsize=(10, 3))
edu_north_df.plot(ax=ax, lw=2, label='North')

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xlim(left=1, right=12)  # set x-axis limit to display only first 12 months
ax.set_xticks(range(0, 12))  # set ticks for 12 months
ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'])
ax.legend(loc=0)
plt.grid()

edu_east_df = edu_east.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '동구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

fig, ax = plt.subplots(figsize=(10, 3))
edu_east_df.plot(ax=ax, lw=2, label='East')

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xlim(left=1, right=12)  # set x-axis limit to display only first 12 months
ax.set_xticks(range(0, 12))  # set ticks for 12 months
ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'])
ax.legend(loc=0)
plt.grid()


edu_south_df = edu_south.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '남구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

fig, ax = plt.subplots(figsize=(10, 3))
edu_south_df.plot(ax=ax, lw=2, label='South')

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xlim(left=1, right=12)  # set x-axis limit to display only first 12 months
ax.set_xticks(range(0, 12))  # set ticks for 12 months
ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'])
ax.legend(loc=0)
plt.grid()

edu_west_df = edu_west.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '서구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

fig, ax = plt.subplots(figsize=(10, 3))
edu_west_df.plot(ax=ax, lw=2, label='West')

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xlim(left=1, right=12)  # set x-axis limit to display only first 12 months
ax.set_xticks(range(0, 12))  # set ticks for 12 months
ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'])
ax.legend(loc=0)
plt.grid()

edu_gwang_df = edu_gwang.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '광산구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

fig, ax = plt.subplots(figsize=(10, 3))
edu_gwang_df.plot(ax=ax, lw=2, label='North')

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xlim(left=1, right=12)  
ax.set_xticks(range(0, 12)) 
ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'])
ax.legend(loc=0)
plt.grid()

plt.show()

# %%
edu_north_df = edu_north.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '북구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

ax = edu_north_df.plot(kind='bar', figsize=(10, 5), width=0.8, edgecolor='gray', linewidth=1)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'], rotation=0)
ax.legend(loc=0)
plt.grid()

edu_east_df = edu_east.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '동구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

ax = edu_east_df.plot(kind='bar', figsize=(10, 5), width=0.8, edgecolor='gray', linewidth=1)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'], rotation=0)
ax.legend(loc=0)
plt.grid()

edu_west_df = edu_west.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '서구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

ax = edu_west_df.plot(kind='bar', figsize=(10, 5), width=0.8, edgecolor='gray', linewidth=1)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'], rotation=0)
ax.legend(loc=0)
plt.grid()

edu_south_df = edu_south.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '남구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

ax = edu_south_df.plot(kind='bar', figsize=(10, 5), width=0.8, edgecolor='gray', linewidth=1)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'], rotation=0)
ax.legend(loc=0)
plt.grid()

edu_gwang_df =edu_gwang.pivot_table(index='월별',columns='연도',values='전력사용량')

title = '광산구 월별 전력 사용량'
ylabel = '월별 사용량(kWh)'
xlabel = '월별'

ax = edu_gwang_df.plot(kind='bar', figsize=(10, 5), width=0.8, edgecolor='gray', linewidth=1)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.set_xticklabels(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'], rotation=0)
ax.legend(loc=0)
plt.grid()

plt.show()
